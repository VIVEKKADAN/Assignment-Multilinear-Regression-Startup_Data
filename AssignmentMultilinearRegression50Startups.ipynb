# %% [markdown]
# Prepare a prediction model for profit of 50_startups data.
# Do transformations for getting better predictions of profit and
# make a table containing R^2 value for each prepared model.
#
# R&D Spend -- Research and devolop spend in the past few years
# Administration -- spend on administration in the past few years
# Marketing Spend -- spend on Marketing in the past few years
# State -- states from which data is collected
# Profit  -- profit of each state in the past few years

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-860ae163-7dd1-4e4e-a8bc-8acca0c0b4db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-860ae163-7dd1-4e4e-a8bc-8acca0c0b4db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
Startup_Data=pd.read_csv('50_Startups.csv')

# %%
Startup_Data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
Startup_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
Startup_Data.describe
# Out:
# <bound method NDFrame.describe of     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
Startup_Data=Startup_Data.drop(['State'],axis=1)

# %%
Startup_Data=Startup_Data.rename(columns={'R&D Spend':'RD_Spend','Marketing Spend':"Marketing_Spend"})
Startup_Data
# Out:
#      RD_Spend  Administration  Marketing_Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
Startup_Data.corr()
# Out:
#                  RD_Spend  Administration  Marketing_Spend    Profit
# RD_Spend         1.000000        0.241955         0.724248  0.972900
# Administration   0.241955        1.000000        -0.032154  0.200717
# Marketing_Spend  0.724248       -0.032154         1.000000  0.747766
# Profit           0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.pairplot(Startup_Data)

# %% [markdown]
# Designing Model

# %%
import statsmodels.formula.api as smf
model=smf.ols('Profit~RD_Spend+Administration+Marketing_Spend',data=Startup_Data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           4.53e-30
# Time:                        13:52:09   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
model.params
# Out:
# Intercept          50122.192990
# RD_Spend               0.805715
# Administration        -0.026816
# Marketing_Spend        0.027228
# dtype: float64

# %%
model.pvalues
# Out:
# Intercept          1.057379e-09
# RD_Spend           2.634968e-22
# Administration     6.017551e-01
# Marketing_Spend    1.047168e-01
# dtype: float64

# %% [markdown]
# From above we can see Null_Hypothesis is selecting by Administration & Marketing_Spend so Adminstration and Marketing_Spend is not in good relation by coefficient becomes zero(Beta=0 is our null hypothesis)

# %%
model_RD=smf.ols('Profit~RD_Spend',data=Startup_Data).fit()
model_RD.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           3.50e-32
# Time:                        13:52:09   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
model_RD.rsquared,model_RD.rsquared_adj
# Out:
# (0.9465353160804393, 0.9454214684987817)

# %%
model_RD.pvalues
# Out:
# Intercept    2.782697e-24
# RD_Spend     3.500322e-32
# dtype: float64

# %%
model_Administration=smf.ols('Profit~Administration',data=Startup_Data).fit()
model_Administration.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):              0.162
# Time:                        13:52:09   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model_Marketing=smf.ols('Profit~Marketing_Spend',data=Startup_Data).fit()
model_Marketing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           4.38e-10
# Time:                        13:52:10   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model_AD_RD=smf.ols('Profit~Marketing_Spend+RD_Spend',data=Startup_Data).fit()
model_AD_RD.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           2.16e-31
# Time:                        13:52:10   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model_AD_RD=smf.ols('Profit~Administration+RD_Spend',data=Startup_Data).fit()
model_AD_RD.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.948
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     426.8
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           7.29e-31
# Time:                        13:52:10   Log-Likelihood:                -526.83
# No. Observations:                  50   AIC:                             1060.
# Df Residuals:                      47   BIC:                             1065.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Calculating VIF

# %%
RSQ_RD=smf.ols('RD_Spend~Administration+Marketing_Spend',data=Startup_Data).fit().rsquared
VIF_RD=1/(1-RSQ_RD)
RSQ_Administration=smf.ols('Administration~RD_Spend+Marketing_Spend',data=Startup_Data).fit().rsquared
VIF_Administration=1/(1-RSQ_Administration)
RSQ_market=smf.ols('Marketing_Spend~RD_Spend+Administration',data=Startup_Data).fit().rsquared
VIF_market=1/(1-RSQ_market)

# %%
Data=pd.DataFrame({'Variables':['RD_Spend','Administration','Marketing_Spend'],'VIF':[VIF_RD,VIF_Administration,VIF_market]})
Data
# Out:
#          Variables       VIF
# 0         RD_Spend  2.468903
# 1   Administration  1.175091
# 2  Marketing_Spend  2.326773

# %% [markdown]
# From above the P Value of Marketing spend is above 0.05 and its VIF also high so we can drop Administration since its not a good variable for Y prediction.But we will check for some other models also to verify this.

# %% [markdown]
# Residual Analysis

# %%
model.resid
# Out:
# 0      -259.422890
# 1      2635.291768
# 2      8903.110904
# 3      9205.289974
# 4     -5951.574183
# 5     -6589.660571
# 6     -1991.586669
# 7     -4268.763048
# 8       470.070301
# 9     -5124.724110
# 10    10612.933633
# 11     8685.687039
# 12    12447.465818
# 13     6819.358337
# 14   -16945.996335
# 15   -16318.119985
# 16    10077.524599
# 17    -4822.077208
# 18    -4747.326806
# 19     7141.643633
# 20     1834.360769
# 21    -6006.431640
# 22    -4354.731717
# 23    -1262.625221
# 24    -4810.926113
# 25     5166.614935
# 26    -4867.035350
# 27    -9399.761457
# 28     1622.353995
# 29     -790.343452
# 30      485.217064
# 31     -204.296276
# 32    -1573.488985
# 33    -1136.087805
# 34     7673.526259
# 35     5967.910432
# 36    15422.015415
# 37      329.602292
# 38    11531.629352
# 39    -2723.251977
# 40     3423.956009
# 41     2996.273761
# 42      878.078179
# 43     9591.940037
# 44      588.975084
# 45    17275.430313
# 46    -6675.456853
# ...

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q - Q Plot of residuals")
plt.show()

# %%
import numpy as np
list(np.where(model.resid>20))
# Out:
# [array([ 1,  2,  3,  8, 10, 11, 12, 13, 16, 19, 20, 25, 28, 30, 34, 35, 36,
#         37, 38, 40, 41, 42, 43, 44, 45])]

# %% [markdown]
# Residual plot for Homoscadacity

# %%
def get_standardized_values(val):
  return (val-val.mean())/val.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),get_standardized_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %% [markdown]
# Residual Vs Regressors

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RD_Spend", fig=fig)
plt.show()fig=plt.figure(figsize=(5,5))
fig=sm.graphics.plot_regress_exog(model,'cc',fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Administration", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Marketing_Spend", fig=fig)
plt.show()

# %% [markdown]
# So from above all inferences and plots we can conclude that ADMINISTRAION is not a good factor for prediction So we can drop it or ignore it.Because Administration p value high r sqrd value less and partial regression plot slop very lss

# %%
#Startup_Data=Startup_Data.drop(['Administration'],axis=1)
#Startup_Data

# %%
model_Final=smf.ols('Profit~Marketing_Spend+RD_Spend',data=Startup_Data).fit()
model_Final.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           2.16e-31
# Time:                        13:52:13   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# To find Outliers

# %% [markdown]
# Lets check cook distance

# %%
from statsmodels.graphics.regressionplots import influence_plot
model_influence_points=model_Final.get_influence()
(C_V,_)=model_influence_points.cooks_distance

# %%
import matplotlib.pyplot as plt
import numpy as np
fig=plt.subplots(figsize=(5,5))
plt.stem(np.arange(len(Startup_Data)),np.round(C_V,2))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17a4f6222683> in <module>
#       2 import numpy as np
#       3 fig=plt.subplots(figsize=(5,5))
# ----> 4 plt.stem(np.arange(len(Startup_Data)),np.round(C_V,2))
#       5 plt.xlabel('Row Index')
#       6 plt.ylabel('Cooks Distance')
#
# NameError: name 'Startup_Data' is not defined

# %%
np.argmax(C_V),np.max(C_V)
# Out:
# (49, 0.38948862279249213)

# %% [markdown]
# From above we can understand that the maximum cooks distance is 0.389 less than 1.
#
# It's fair enough we can go for leverage distance too to identify influence points.

# %% [markdown]
# Leverage Distance

# %%
Startup_Data.shape
# Out:
# (50, 4)

# %%
k=3
n=50
leverage_distance=3*(k+1)/n
leverage_distance
# Out:
# 0.24

# %% [markdown]
# INFLUENCE PLOT

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model_Final)
plt.show()

# %% [markdown]
# HERE All  data points are less than leverage cutoff line so NO NEED TO OMIT ANY POINTS AS HIGHLY INFLUENCE

# %% [markdown]
# So our model is done and let us go for model prediction

# %% [markdown]
# PREDICTION

# %%
NEW_DATA=pd.DataFrame({'Marketing_Spend':572136.5,'RD_Spend':489512.02},index=[1])
NEW_DATA
# Out:
#    Marketing_Spend   RD_Spend
# 1         572136.5  489512.02

# %%
model_Final.predict(NEW_DATA)
# Out:
# 1    454024.715769
# dtype: float64
